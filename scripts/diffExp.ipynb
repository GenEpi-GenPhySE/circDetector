# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

#BiocManager::install("limma")
#BiocManager::install("mixOmics")
#BiocManager::install("edgeR")

# %%
## Loading required package: limma
library(limma)
library(RColorBrewer)
library(mixOmics)

library(ggplot2)

library(edgeR)
#library(HTSFilter)

# First reading the data

#The root directory
dir="."
setwd(dir)
# Out:
# Loading required package: MASS
#
# Loading required package: lattice
#
# Loading required package: ggplot2
#
#
# Loaded mixOmics 6.10.9
# Thank you for using mixOmics!
# Tutorials: http://mixomics.org
# Bookdown vignette: https://mixomicsteam.github.io/Bookdown
# Questions, issues: Follow the prompts at http://mixomics.org/contact-us
# Cite us:  citation('mixOmics')

# %%
rawData=read.table("cirRNAcounts.tsv",header=T,row.names= 1)
CountTable = round(rawData)
pseudoCounts <- log2(CountTable+1)

# %%
head(pseudoCounts)
# Out:
#                       cow.testis.adult1 cow.testis.neonat2 cow.liver.B004
# 1:2065162-2068739:+   2.807355          3.459432           0.000000
# 1:3797634-3799302:+   3.459432          4.523562           3.321928
# 1:4289436-4296946:+   2.807355          3.459432           0.000000
# 1:10360227-10362943:+ 3.906891          6.108524           3.321928
# 1:10672567-10683626:- 4.584963          4.754888           2.807355
# 1:31354407-31355646:+ 2.807355          0.000000           0.000000
#                       cow.liver.B008 cow.liver.B005 cow.testis.adult3
# 1:2065162-2068739:+   0.000000       0.000000       0.000000
# 1:3797634-3799302:+   3.700440       2.807355       0.000000
# 1:4289436-4296946:+   0.000000       0.000000       0.000000
# 1:10360227-10362943:+ 0.000000       0.000000       3.700440
# 1:10672567-10683626:- 3.459432       0.000000       4.392317
# 1:31354407-31355646:+ 0.000000       0.000000       0.000000
#                       cow.testis.neonat3 cow.testis.adult2 cow.testis.neonat1
# 1:2065162-2068739:+   3.000000           0.000000          3.807355
# 1:3797634-3799302:+   4.247928           3.169925          5.247928
# 1:4289436-4296946:+   3.584963           0.000000          0.000000
# 1:10360227-10362943:+ 5.614710           3.000000          6.044394
# 1:10672567-10683626:- 4.754888           4.459432          4.087463
# 1:31354407-31355646:+ 0.000000           0.000000          0.000000

# %%
hist(pseudoCounts$cow.testis.neonat2,main="pseudo-counts")
# Out:
# Plot with title “pseudo-counts”

# %%
plotMDS(pseudoCounts)
# Out:
# plot without title
